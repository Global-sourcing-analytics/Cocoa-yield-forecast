# %%
#Load the required libraries
import pandas as pd
import numpy as np
import seaborn as sns

from BC_solutions import Databases

# %% [markdown]
# ## Loading the data

# %%
# Database credentials
server = 'CorpPolDB'
database = 'DW'
UID = 'POD'
PWD = 'POD2019'

database_manager = Databases.DatabaseManager(server, database, UID, PWD)
# Out:
# POD POD2019
# Connection with database established.

# %%
df = database_manager.get_data('SELECT * FROM [DW].[pod].[v_POD]')

# %%
#View the data
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    IsTempRecord Reporter        Country State  Week  Year  Month SiteLetter  \
# 0         False      CIV  Cote d Ivoire   n/a    44  1997     10         AG
# 1         False      CIV  Cote d Ivoire   n/a    44  1997     10         AG
# 2         False      CIV  Cote d Ivoire   n/a    44  1997     10         AG
# 3         False      CIV  Cote d Ivoire   n/a    44  1997     10         AG
# 4         False      CIV  Cote d Ivoire   n/a    44  1997     10         AG
#
#    SiteNumber  TreeNumber PCSample Variety  Moisture  Texture  Canopy  \
# 0           2           0        Y     n/a       NaN      NaN     NaN
# 1          10           0        Y     n/a       NaN      NaN     NaN
# 2          11           0        Y     n/a       NaN      NaN     NaN
# 3          12           0        Y     n/a       NaN      NaN     NaN
# 4          13           0        Y     n/a       NaN      NaN     NaN
#
#    Maintenance  Flowers  Leaf flushing  WB  Monilia T/S  Monilia M/L  \
# 0          NaN      NaN            NaN NaN          NaN          NaN
# 1          NaN      NaN            NaN NaN          NaN          NaN
# 2          NaN      NaN            NaN NaN          NaN          NaN
# 3          NaN      NaN            NaN NaN          NaN          NaN
# 4          NaN      NaN            NaN NaN          NaN          NaN
#
#    Monilia M  Black Pod  Other D/D Harvest Drying Fermentation Fertilizer  \
# 0        NaN        NaN        NaN    None   None         None       None
# 1        NaN        NaN        NaN    None   None         None       None
# 2        NaN        NaN        NaN    None   None         None       None
# 3        NaN        NaN        NaN    None   None         None       None
# 4        NaN        NaN        NaN    None   None         None       None
#
#   Fungicide Irrigation  Tiny  Small  Medium  Large  Mature  Ripe  Wilt  \
# 0      None       None   2.0    4.0     NaN    2.0    96.0   4.0   3.0
# 1      None       None   1.0    3.0     NaN    9.0   171.0   8.0   3.0
# 2      None       None   1.0    2.0     NaN    2.0    71.0  24.0   2.0
# 3      None       None   8.0   27.0     NaN    8.0   142.0  14.0  25.0
# 4      None       None   4.0    7.0     NaN   16.0    97.0  40.0  15.0
#
#    Damaged  Healthy  Total  Cherelles  Adults              ImportDate    ID  \
# 0      0.0    108.0  111.0        6.0   102.0 2019-06-11 13:44:14.510  1729
# 1      2.0    192.0  197.0        4.0   188.0 2019-06-11 13:44:14.510  1732
# 2      4.0    100.0  106.0        3.0    97.0 2019-06-11 13:44:14.510  1733
# 3      7.0    199.0  231.0       35.0   164.0 2019-06-11 13:44:14.510  1734
# 4     13.0    164.0  192.0       11.0   153.0 2019-06-11 13:44:14.510  1735
#
#                                  ts   Main   Region    CountDay  SmallBefore  \
# 0  b'\x00\x00\x00\x03\x89N\x1e\xf2'  108.0  Lagunes  Abengourou          NaN
# 1  b'\x00\x00\x00\x03\x89N\x1e\xf5'  192.0    Comoé  Abengourou          NaN
# 2  b'\x00\x00\x00\x03\x89N\x1e\xf6'  100.0    Comoé  Abengourou          NaN
# 3  b'\x00\x00\x00\x03\x89N\x1e\xf7'  199.0    Comoé  Abengourou          NaN
# 4  b'\x00\x00\x00\x03\x89N\x1e\xf8'  164.0     Lacs  Abengourou          NaN
#
#    TinyBefore  MediumBefore  LargeBefore  SmallBefore2  LargeBefore2  Mid
# 0         NaN           NaN          NaN           NaN           NaN  0.0
# 1         NaN           NaN          NaN           NaN           NaN  0.0
# 2         NaN           NaN          NaN           NaN           NaN  0.0
# 3         NaN           NaN          NaN           NaN           NaN  0.0
# 4         NaN           NaN          NaN           NaN           NaN  0.0

# %% [markdown]
# ## Basic information about data

# %%
#Basic information
df.info(verbose=True, max_cols=100)

#Describe the data

df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111319 entries, 0 to 111318
# Data columns (total 55 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   IsTempRecord   111319 non-null  bool
#  1   Reporter       111319 non-null  object
#  2   Country        111319 non-null  object
#  3   State          111319 non-null  object
#  4   Week           111319 non-null  int64
#  5   Year           111319 non-null  int64
#  6   Month          111319 non-null  int64
#  7   SiteLetter     111319 non-null  object
#  8   SiteNumber     111319 non-null  int64
#  9   TreeNumber     111319 non-null  int64
#  10  PCSample       108940 non-null  object
#  11  Variety        111319 non-null  object
#  12  Moisture       87034 non-null   float64
#  13  Texture        108763 non-null  float64
#  14  Canopy         108826 non-null  float64
#  15  Maintenance    108827 non-null  float64
#  16  Flowers        108796 non-null  float64
#  17  Leaf flushing  108745 non-null  float64
#  18  WB             59189 non-null   float64
#  19  Monilia T/S    3369 non-null    float64
#  20  Monilia M/L    3370 non-null    float64
#  21  Monilia M      3368 non-null    float64
#  22  Black Pod      9807 non-null    float64
#  23  Other D/D      3369 non-null    float64
#  24  Harvest        69003 non-null   object
#  25  Drying         9035 non-null    object
#  26  Fermentation   2579 non-null    object
#  27  Fertilizer     68722 non-null   object
#  28  Fungicide      68709 non-null   object
#  29  Irrigation     3345 non-null    object
#  30  Tiny           111319 non-null  float64
#  31  Small          111318 non-null  float64
#  32  Medium         62559 non-null   float64
#  33  Large          111313 non-null  float64
#  34  Mature         111317 non-null  float64
#  35  Ripe           111314 non-null  float64
#  36  Wilt           52077 non-null   float64
#  37  Damaged        111225 non-null  float64
#  38  Healthy        111319 non-null  float64
#  39  Total          111319 non-null  float64
#  40  Cherelles      111319 non-null  float64
#  41  Adults         111319 non-null  float64
#  42  ImportDate     111319 non-null  datetime64[ns]
#  43  ID             111319 non-null  int64
#  44  ts             111319 non-null  object
#  45  Main           111319 non-null  float64
#  46  Region         111319 non-null  object
#  47  CountDay       37764 non-null   object
#  48  SmallBefore    109748 non-null  float64
#  49  TinyBefore     109749 non-null  float64
#  50  MediumBefore   61845 non-null   float64
#  51  LargeBefore    109743 non-null  float64
#  52  SmallBefore2   108207 non-null  float64
#  53  LargeBefore2   108202 non-null  float64
#  54  Mid            111319 non-null  float64
# dtypes: bool(1), datetime64[ns](1), float64(32), int64(6), object(15)
# memory usage: 46.0+ MB
#                 Week           Year          Month     SiteNumber  \
# count  111319.000000  111319.000000  111319.000000  111319.000000
# mean       85.800232    2016.418239       6.261959      33.440653
# std       331.531806       4.828331       3.471316      70.940718
# min         0.000000    1997.000000       1.000000       0.000000
# 25%         0.000000    2014.000000       3.000000       6.000000
# 50%         0.000000    2017.000000       6.000000      15.000000
# 75%        22.000000    2020.000000       9.000000      25.000000
# max      1946.000000    2023.000000      12.000000     523.000000
#
#           TreeNumber      Moisture        Texture         Canopy  \
# count  111319.000000  87034.000000  108763.000000  108826.000000
# mean        1.595101     23.457302       2.850933       2.965422
# std         1.817781     14.779524       1.256381       0.609089
# min         0.000000      0.000000       0.000000       0.000000
# 25%         0.000000     14.200000       2.000000       3.000000
# 50%         1.000000     21.000000       3.000000       3.000000
# 75%         3.000000     30.000000       3.000000       3.000000
# max         5.000000    310.000000     313.000000      45.000000
#
#          Maintenance        Flowers  Leaf flushing            WB  Monilia T/S  \
# count  108827.000000  108796.000000  108745.000000  59189.000000  3369.000000
# mean        2.822976       1.948969       1.757092      3.139587     0.343129
# std         0.929600       0.974865       1.043245      1.607908     1.271296
# min         0.000000       0.000000       0.000000      0.000000     0.000000
# 25%         2.000000       1.000000       1.000000      1.000000     0.000000
# 50%         3.000000       2.000000       2.000000      3.000000     0.000000
# 75%         3.000000       2.000000       2.000000      5.000000     0.000000
# max        31.000000      22.000000      21.000000     55.000000    19.000000
#
#        Monilia M/L    Monilia M    Black Pod    Other D/D           Tiny  \
# count  3370.000000  3368.000000  9807.000000  3369.000000  111319.000000
# mean      0.429970     0.609561     0.999898     2.474918      11.005076
# std       1.511995     1.672252     2.535431    11.721305      26.085964
# min       0.000000     0.000000     0.000000     0.000000       0.000000
# 25%       0.000000     0.000000     0.000000     0.000000       0.000000
# 50%       0.000000     0.000000     0.000000     0.000000       2.000000
# 75%       0.000000     0.000000     1.000000     1.000000      11.000000
# max      29.000000    26.000000    67.000000   280.000000     790.000000
#
#                Small        Medium          Large         Mature  \
# count  111318.000000  62559.000000  111313.000000  111317.000000
# mean        9.926050      3.364344       6.374727      11.801477
# std        21.777955      8.184783      14.375298      22.370084
# min         0.000000      0.000000       0.000000       0.000000
# 25%         0.000000      0.000000       0.000000       0.000000
# 50%         2.000000      1.000000       2.000000       3.000000
# 75%        11.000000      3.000000       7.000000      13.000000
# max       804.000000    333.000000    2712.000000     438.000000
#
#                 Ripe          Wilt        Damaged        Healthy  \
# count  111314.000000  52077.000000  111225.000000  111319.000000
# mean        3.052437      2.612919       0.942108      44.049677
# std         7.263879      5.730736       3.162272      65.213983
# min         0.000000      0.000000       0.000000       0.000000
# 25%         0.000000      0.000000       0.000000       4.000000
# 50%         0.000000      1.000000       0.000000      18.000000
# 75%         3.000000      3.000000       1.000000      59.000000
# max       185.000000    171.000000     132.000000    2993.000000
#
#                Total      Cherelles         Adults             ID  \
# count  111319.000000  111319.000000  111319.000000  111319.000000
# mean       46.418195      20.931036      23.118641  106458.393787
# std        68.295708      42.875472      35.571433   53953.357989
# min         0.000000       0.000000       0.000000       1.000000
# 25%         4.000000       0.000000       2.000000   85420.500000
# 50%        19.000000       5.000000       9.000000  113680.000000
# 75%        63.000000      23.000000      30.000000  149293.500000
# max      2999.000000    1192.000000    2726.000000  184550.000000
#
#                 Main    SmallBefore     TinyBefore  MediumBefore  \
# count  111319.000000  109748.000000  109749.000000  61845.000000
# mean       29.501886       9.951234      11.007453      3.362212
# std        55.569753      21.835134      26.112888      8.204251
# min         0.000000       0.000000       0.000000      0.000000
# 25%         0.000000       0.000000       0.000000      0.000000
# 50%         6.000000       2.000000       2.000000      1.000000
# 75%        33.000000      11.000000      11.000000      3.000000
# max      2993.000000     804.000000     790.000000    333.000000
#
#          LargeBefore   SmallBefore2   LargeBefore2            Mid
# count  109743.000000  108207.000000  108202.000000  111319.000000
# mean        6.379013       9.979641       6.386176      14.547791
# std        14.426506      21.932548      14.477452      31.618122
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         2.000000       2.000000       2.000000       3.000000
# 75%         7.000000      11.000000       7.000000      15.000000
# max      2712.000000     804.000000    2712.000000    1195.000000

# %% [markdown]
# ## Duplicated values

# %%
#Find the duplicates

df.duplicated().sum()
# Out:
# 0

# %%
for column in df.columns:
    if df[column].dtype == 'object':
        print(column)
        print(df[column].unique())
# Out:
# Reporter
# ['CIV' 'GHA' 'IDN' 'CMR' 'BRA' 'ECU']
# Country
# ['Cote d Ivoire' 'Ghana' 'Indonesia' 'Cameroon' 'Brazil' 'Ecuador']
# State
# ['n/a' 'Sumatra' 'Bahia' 'Para' 'Sulawesi']
# SiteLetter
# ['AG' 'DA' 'FR' 'DL' 'GA' 'SP' 'AS' 'BA' 'CR' 'ER' 'WR' 'AJ' 'GT' 'KIS'
#  'BT' 'LA' 'LH' 'LU' 'ME' 'PA' 'PR' 'SI' 'SL' 'SM' 'VA' 'MA' 'WS' 'TGA'
#  'WTT' 'ETT' 'KNY' 'MBG' 'MBY' 'NKK' 'SKK' 'TBL' 'EFK' 'BKT' 'S' 'C' 'N'
#  'WN' 'KK' 'MK' 'MJ' 'WO' 'PP' 'PL' 'PO' 'NAR' 'PAT' 'PED' 'PUE' 'QND'
#  'QUE' 'QUI' 'SAN' 'VAL' 'VEN' 'VIC' 'BAB' 'BUE' 'CAL' 'CER' 'CHO' 'ELC'
#  'EMP' 'FLA' 'GUA' 'MAC' 'MOC' 'MON' 'MUI' 'CAT' 'kk' 'SLZ']
# PCSample
# ['Y' '' None]
# Variety
# ['n/a' 'Nacional' 'CCN-51']
# Harvest
# [None False True]
# Drying
# [None False True]
# Fermentation
# [None False True]
# Fertilizer
# [None False True]
# Fungicide
# [None True False]
# Irrigation
# [None False True]
# ts
# [b'\x00\x00\x00\x03\x89N\x1e\xf2' b'\x00\x00\x00\x03\x89N\x1e\xf5'
#  b'\x00\x00\x00\x03\x89N\x1e\xf6' ... b'\x00\x00\x00(9\xe6\x95\xfc'
#  b'\x00\x00\x00(9\xe6\x95\xfe' b'\x00\x00\x00(9\xe6\x95\xf7']
# Region
# ['Lagunes' 'Comoé' 'Lacs' 'Gôh-Djiboua' 'Sassandra-Marahoué'
#  'Bas-Sassandra' 'Ashanti' 'Brong Ahafo' 'Central' 'Eastern' 'Western N.'
#  'Western S.' 'Medan' 'Lampung' 'Padang' 'Aceh' 'Montagnes' 'WEST'
#  'CENTRE' 'SOUTH-WEST' 'SOUTH' 'South' 'Center' 'North' 'Para' 'Southeast'
#  'West' 'Guayas' 'Canar' 'Los Rios' 'Manabi' 'Esmeraldas' 'Bolivar'
#  'Santo Domingo']
# CountDay
# ['Abengourou' 'Gagnoa-Daloa' 'Man-Douekoue' 'Coast' 'Gagnoa-Sinfra'
#  'Soubre-SanPedro' 'Gagnoa-Soubre' None 'n/a' 'Daloa-Man' 'Nacional'
#  'CCN-51']

# %%
sns.countplot(x=df['Country'])
# Out:
# <Axes: xlabel='Country', ylabel='count'>

# %% [markdown]
# ## Find the Null values

# %%
df.isnull().sum()
# Out:
# IsTempRecord          0
# Reporter              0
# Country               0
# State                 0
# Week                  0
# Year                  0
# Month                 0
# SiteLetter            0
# SiteNumber            0
# TreeNumber            0
# PCSample           2379
# Variety               0
# Moisture          24285
# Texture            2556
# Canopy             2493
# Maintenance        2492
# Flowers            2523
# Leaf flushing      2574
# WB                52130
# Monilia T/S      107950
# Monilia M/L      107949
# Monilia M        107951
# Black Pod        101512
# Other D/D        107950
# Harvest           42316
# Drying           102284
# Fermentation     108740
# Fertilizer        42597
# Fungicide         42610
# Irrigation       107974
# Tiny                  0
# Small                 1
# Medium            48760
# Large                 6
# Mature                2
# Ripe                  5
# Wilt              59242
# Damaged              94
# Healthy               0
# Total                 0
# Cherelles             0
# Adults                0
# ImportDate            0
# ID                    0
# ts                    0
# Main                  0
# Region                0
# CountDay          73555
# SmallBefore        1571
# TinyBefore         1570
# MediumBefore      49474
# LargeBefore        1576
# SmallBefore2       3112
# LargeBefore2       3117
# Mid                   0
# dtype: int64

# %%
df[['Total']].boxplot()
# Out:
# <Axes: >
