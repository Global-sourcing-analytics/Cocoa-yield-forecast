# %%
#Load the required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from datetime import datetime
from dataprep.eda import create_report

# %% [markdown]
# ## Loading the data

# %%
df = pd.read_csv('POD_raw.csv')
# Out:
# C:\Users\BC127735\AppData\Local\Temp\ipykernel_6172\761485599.py:1: DtypeWarning: Columns (11,25,26,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('POD_raw.csv')

# %%
#View the data
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    IsTempRecord Reporter        Country State  Week  Year  Month SiteLetter  \
# 0         False      CIV  Cote d Ivoire   NaN    44  1997     10         AG
# 1         False      CIV  Cote d Ivoire   NaN    44  1997     10         AG
# 2         False      CIV  Cote d Ivoire   NaN    44  1997     10         AG
# 3         False      CIV  Cote d Ivoire   NaN    44  1997     10         AG
# 4         False      CIV  Cote d Ivoire   NaN    44  1997     10         AG
#
#    SiteNumber  TreeNumber PCSample Variety  Moisture  Texture  Canopy  \
# 0           2           0        Y     NaN       NaN      NaN     NaN
# 1          10           0        Y     NaN       NaN      NaN     NaN
# 2          11           0        Y     NaN       NaN      NaN     NaN
# 3          12           0        Y     NaN       NaN      NaN     NaN
# 4          13           0        Y     NaN       NaN      NaN     NaN
#
#    Maintenance  Flowers  Leaf flushing  WB  Monilia T/S  Monilia M/L  \
# 0          NaN      NaN            NaN NaN          NaN          NaN
# 1          NaN      NaN            NaN NaN          NaN          NaN
# 2          NaN      NaN            NaN NaN          NaN          NaN
# 3          NaN      NaN            NaN NaN          NaN          NaN
# 4          NaN      NaN            NaN NaN          NaN          NaN
#
#    Monilia M  Black Pod  Other D/D Harvest Drying Fermentation Fertilizer  \
# 0        NaN        NaN        NaN     NaN    NaN          NaN        NaN
# 1        NaN        NaN        NaN     NaN    NaN          NaN        NaN
# 2        NaN        NaN        NaN     NaN    NaN          NaN        NaN
# 3        NaN        NaN        NaN     NaN    NaN          NaN        NaN
# 4        NaN        NaN        NaN     NaN    NaN          NaN        NaN
#
#   Fungicide Irrigation  Tiny  Small  Medium  Large  Mature  Ripe  Wilt  \
# 0       NaN        NaN   2.0    4.0     NaN    2.0    96.0   4.0   3.0
# 1       NaN        NaN   1.0    3.0     NaN    9.0   171.0   8.0   3.0
# 2       NaN        NaN   1.0    2.0     NaN    2.0    71.0  24.0   2.0
# 3       NaN        NaN   8.0   27.0     NaN    8.0   142.0  14.0  25.0
# 4       NaN        NaN   4.0    7.0     NaN   16.0    97.0  40.0  15.0
#
#    Damaged  Healthy  Total  Cherelles  Adults               ImportDate    ID  \
# 0      0.0    108.0  111.0        6.0   102.0  2019-06-11 13:44:14.510  1729
# 1      2.0    192.0  197.0        4.0   188.0  2019-06-11 13:44:14.510  1732
# 2      4.0    100.0  106.0        3.0    97.0  2019-06-11 13:44:14.510  1733
# 3      7.0    199.0  231.0       35.0   164.0  2019-06-11 13:44:14.510  1734
# 4     13.0    164.0  192.0       11.0   153.0  2019-06-11 13:44:14.510  1735
#
#                                  ts   Main   Region    CountDay  SmallBefore  \
# 0  b'\x00\x00\x00\x03\x89N\x1e\xf2'  108.0  Lagunes  Abengourou          NaN
# 1  b'\x00\x00\x00\x03\x89N\x1e\xf5'  192.0    Comoé  Abengourou          NaN
# 2  b'\x00\x00\x00\x03\x89N\x1e\xf6'  100.0    Comoé  Abengourou          NaN
# 3  b'\x00\x00\x00\x03\x89N\x1e\xf7'  199.0    Comoé  Abengourou          NaN
# 4  b'\x00\x00\x00\x03\x89N\x1e\xf8'  164.0     Lacs  Abengourou          NaN
#
#    TinyBefore  MediumBefore  LargeBefore  SmallBefore2  LargeBefore2  Mid
# 0         NaN           NaN          NaN           NaN           NaN  0.0
# 1         NaN           NaN          NaN           NaN           NaN  0.0
# 2         NaN           NaN          NaN           NaN           NaN  0.0
# 3         NaN           NaN          NaN           NaN           NaN  0.0
# 4         NaN           NaN          NaN           NaN           NaN  0.0

# %% [markdown]
# ## Basic information about data

# %%
#Basic information
df.info(verbose=True, max_cols=100)

#Describe the data

df.describe().T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111613 entries, 0 to 111612
# Data columns (total 55 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   IsTempRecord   111613 non-null  bool
#  1   Reporter       111613 non-null  object
#  2   Country        111613 non-null  object
#  3   State          65823 non-null   object
#  4   Week           111613 non-null  int64
#  5   Year           111613 non-null  int64
#  6   Month          111613 non-null  int64
#  7   SiteLetter     111613 non-null  object
#  8   SiteNumber     111613 non-null  int64
#  9   TreeNumber     111613 non-null  int64
#  10  PCSample       109232 non-null  object
#  11  Variety        1195 non-null    object
#  12  Moisture       87328 non-null   float64
#  13  Texture        109057 non-null  float64
#  14  Canopy         109120 non-null  float64
#  15  Maintenance    109121 non-null  float64
#  16  Flowers        109090 non-null  float64
#  17  Leaf flushing  109039 non-null  float64
#  18  WB             59379 non-null   float64
#  19  Monilia T/S    3437 non-null    float64
#  20  Monilia M/L    3438 non-null    float64
#  21  Monilia M      3436 non-null    float64
#  22  Black Pod      9875 non-null    float64
#  23  Other D/D      3437 non-null    float64
#  24  Harvest        69261 non-null   object
#  25  Drying         9075 non-null    object
#  26  Fermentation   2619 non-null    object
#  27  Fertilizer     68980 non-null   object
#  28  Fungicide      68967 non-null   object
#  29  Irrigation     3413 non-null    object
#  30  Tiny           111613 non-null  float64
#  31  Small          111612 non-null  float64
#  32  Medium         62817 non-null   float64
#  33  Large          111607 non-null  float64
#  34  Mature         111611 non-null  float64
#  35  Ripe           111608 non-null  float64
#  36  Wilt           52181 non-null   float64
#  37  Damaged        111519 non-null  float64
#  38  Healthy        111613 non-null  float64
#  39  Total          111613 non-null  float64
#  40  Cherelles      111613 non-null  float64
#  41  Adults         111613 non-null  float64
#  42  ImportDate     111613 non-null  object
#  43  ID             111613 non-null  int64
#  44  ts             111613 non-null  object
#  45  Main           111613 non-null  float64
#  46  Region         111613 non-null  object
#  47  CountDay       24485 non-null   object
#  48  SmallBefore    110042 non-null  float64
#  49  TinyBefore     110043 non-null  float64
#  50  MediumBefore   62103 non-null   float64
#  51  LargeBefore    110037 non-null  float64
#  52  SmallBefore2   108501 non-null  float64
#  53  LargeBefore2   108496 non-null  float64
#  54  Mid            111613 non-null  float64
# dtypes: bool(1), float64(32), int64(6), object(16)
# memory usage: 46.1+ MB
#                   count           mean           std     min      25%  \
# Week           111613.0      85.577451    331.123291     0.0      0.0
# Year           111613.0    2016.435577      4.833754  1997.0   2014.0
# Month          111613.0       6.253367      3.470771     1.0      3.0
# SiteNumber     111613.0      33.390546     70.857099     0.0      6.0
# TreeNumber     111613.0       1.596006      1.817899     0.0      0.0
# Moisture        87328.0      23.504271     14.851973     0.0     14.2
# Texture        109057.0       2.852105      1.255919     0.0      2.0
# Canopy         109120.0       2.965799      0.609062     0.0      3.0
# Maintenance    109121.0       2.823673      0.929026     0.0      2.0
# Flowers        109090.0       1.949675      0.974958     0.0      1.0
# Leaf flushing  109039.0       1.756069      1.043637     0.0      1.0
# WB              59379.0       3.135603      1.608066     0.0      1.0
# Monilia T/S      3437.0       0.336922      1.259636     0.0      0.0
# Monilia M/L      3438.0       0.422048      1.498191     0.0      0.0
# Monilia M        3436.0       0.598661      1.657725     0.0      0.0
# Black Pod        9875.0       0.998987      2.531711     0.0      0.0
# Other D/D        3437.0       2.434681     11.612468     0.0      0.0
# Tiny           111613.0      10.993845     26.066197     0.0      0.0
# Small          111612.0       9.921639     21.757878     0.0      0.0
# Medium          62817.0       3.388557      8.205656     0.0      0.0
# Large          111607.0       6.371867     14.361520     0.0      0.0
# Mature         111611.0      11.791248     22.351182     0.0      0.0
# Ripe           111608.0       3.048643      7.257405     0.0      0.0
# Wilt            52181.0       2.609360      5.726638     0.0      0.0
# Damaged        111519.0       0.941678      3.160438     0.0      0.0
# Healthy        111613.0      44.033580     65.159429     0.0      4.0
# Total          111613.0      46.399550     68.237491     0.0      4.0
# Cherelles      111613.0      20.915395     42.838287     0.0      0.0
# Adults         111613.0      23.118185     35.550790     0.0      2.0
# ID             111613.0  106664.496286  54031.295924     1.0  85494.0
# Main           111613.0      29.432830     55.514362     0.0      0.0
# SmallBefore    110042.0       9.951319     21.818821     0.0      0.0
# TinyBefore     110043.0      10.993375     26.083340     0.0      0.0
# MediumBefore    62103.0       3.370288      8.206737     0.0      0.0
# LargeBefore    110037.0       6.369021     14.413668     0.0      0.0
# SmallBefore2   108501.0       9.964885     21.908524     0.0      0.0
# LargeBefore2   108496.0       6.378512     14.465519     0.0      0.0
# Mid            111613.0      14.600750     31.653280     0.0      0.0
#
#                     50%       75%       max
# Week                0.0      22.0    1946.0
# Year             2017.0    2020.0    2023.0
# Month               6.0       9.0      12.0
# SiteNumber         15.0      25.0     523.0
# TreeNumber          1.0       3.0       5.0
# Moisture           21.0      30.0     310.0
# Texture             3.0       3.0     313.0
# Canopy              3.0       3.0      45.0
# Maintenance         3.0       3.0      31.0
# Flowers             2.0       2.0      22.0
# Leaf flushing       2.0       2.0      21.0
# WB                  3.0       5.0      55.0
# Monilia T/S         0.0       0.0      19.0
# Monilia M/L         0.0       0.0      29.0
# Monilia M           0.0       0.0      26.0
# Black Pod           0.0       1.0      67.0
# Other D/D           0.0       1.0     280.0
# Tiny                2.0      11.0     790.0
# Small               2.0      11.0     804.0
# Medium              1.0       3.0     333.0
# Large               2.0       7.0    2712.0
# Mature              3.0      13.0     438.0
# Ripe                0.0       3.0     185.0
# Wilt                1.0       3.0     171.0
# Damaged             0.0       1.0     132.0
# Healthy            18.0      59.0    2993.0
# Total              19.0      63.0    2999.0
# Cherelles           5.0      23.0    1192.0
# Adults              9.0      30.0    2726.0
# ID             113827.0  149798.0  184846.0
# Main                6.0      33.0    2993.0
# SmallBefore         2.0      11.0     804.0
# TinyBefore          2.0      11.0     790.0
# MediumBefore        1.0       3.0     333.0
# LargeBefore         2.0       7.0    2712.0
# SmallBefore2        2.0      11.0     804.0
# LargeBefore2        2.0       7.0    2712.0
# Mid                 3.0      16.0    1195.0

# %% [markdown]
# ## Adding datetime to DataFrame

# %%
df['Date'] = [datetime(row["Year"], row["Month"], 1) for index, row in df.iterrows()]
# df.set_index('Date', inplace=True)

# %% [markdown]
# ## Performing EDA

# %%
create_report(df).show_browser()
# Out:
# 100%|##########| 1/1 [00:00<?, ?it/s]
#   0%|          | 0/10345 [00:00<?, ?it/s]
# c:\Users\BC127735\Anaconda3\envs\venv39ML\lib\site-packages\scipy\stats\_stats_py.py:5283: RuntimeWarning: overflow encountered in longlong_scalars
#   (2 * xtie * ytie) / m + x0 * y0 / (9 * m * (size - 2)))
# c:\Users\BC127735\Anaconda3\envs\venv39ML\lib\site-packages\scipy\stats\_stats_py.py:5283: RuntimeWarning: overflow encountered in longlong_scalars
#   (2 * xtie * ytie) / m + x0 * y0 / (9 * m * (size - 2)))
# c:\Users\BC127735\Anaconda3\envs\venv39ML\lib\site-packages\scipy\stats\_stats_py.py:5283: RuntimeWarning: overflow encountered in longlong_scalars
#   (2 * xtie * ytie) / m + x0 * y0 / (9 * m * (size - 2)))
# c:\Users\BC127735\Anaconda3\envs\venv39ML\lib\site-packages\dask\core.py:119: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# c:\Users\BC127735\Anaconda3\envs\venv39ML\lib\site-packages\dask\core.py:119: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# c:\Users\BC127735\Anaconda3\envs\venv39ML\lib\site-packages\scipy\stats\_stats_py.py:5283: RuntimeWarning: overflow encountered in longlong_scalars
#   (2 * xtie * ytie) / m + x0 * y0 / (9 * m * (size - 2)))
# c:\Users\BC127735\Anaconda3\envs\venv39ML\lib\site-packages\dataprep\eda\utils.py:392: RuntimeWarning: ks_2samp: Exact calculation unsuccessful. Switching to method=asymp.
#   return cast(Tuple[float, float], ks_2samp_(data1, data2))
# c:\Users\BC127735\Anaconda3\envs\venv39ML\lib\site-packages\scipy\stats\_stats_py.py:5283: RuntimeWarning: overflow encountered in longlong_scalars
#   (2 * xtie * ytie) / m + x0 * y0 / (9 * m * (size - 2)))
# c:\Users\BC127735\Anaconda3\envs\venv39ML\lib\site-packages\dataprep\eda\distribution\render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# c:\Users\BC127735\Anaconda3\envs\venv39ML\lib\site-packages\dataprep\eda\distribution\render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# c:\Users\BC127735\Anaconda3\envs\venv39ML\lib\site-packages\dataprep\eda\distribution\render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# c:\Users\BC127735\Anaconda3\envs\venv39ML\lib\site-packages\dataprep\eda\distribution\render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# c:\Users\BC127735\Anaconda3\envs\venv39ML\lib\site-packages\dataprep\eda\distribution\render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# c:\Users\BC127735\Anaconda3\envs\venv39ML\lib\site-packages\dataprep\eda\distribution\render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# c:\Users\BC127735\Anaconda3\envs\venv39ML\lib\site-packages\dataprep\eda\distribution\render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# c:\Users\BC127735\Anaconda3\envs\venv39ML\lib\site-packages\dataprep\eda\distribution\render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# c:\Users\BC127735\Anaconda3\envs\venv39ML\lib\site-packages\dataprep\eda\distribution\render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# c:\Users\BC127735\Anaconda3\envs\venv39ML\lib\site-packages\dataprep\eda\distribution\render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# c:\Users\BC127735\Anaconda3\envs\venv39ML\lib\site-packages\dataprep\eda\distribution\render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# c:\Users\BC127735\Anaconda3\envs\venv39ML\lib\site-packages\dataprep\eda\distribution\render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# c:\Users\BC127735\Anaconda3\envs\venv39ML\lib\site-packages\dataprep\eda\distribution\render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# c:\Users\BC127735\Anaconda3\envs\venv39ML\lib\site-packages\dataprep\eda\distribution\render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# c:\Users\BC127735\Anaconda3\envs\venv39ML\lib\site-packages\dataprep\eda\distribution\render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))
# c:\Users\BC127735\Anaconda3\envs\venv39ML\lib\site-packages\dataprep\eda\distribution\render.py:274: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame({col: [nrows - npresent]}, index=["Others"]))

# %%
# Które kraje posiadają rozdział na stany oraz czy dane dotyczące tych krajów posiadają puste wartości w kolumnie "State"
list_country_with_state = list(df[df["State"].notna()]["Country"].unique())
dict_country_state = {country: list(df[df["Country"] == country]["State"].unique()) for country in list_country_with_state}

for country in dict_country_state.keys():
    print(country, "| States: ", dict_country_state[country], "| Any nulls in state?: ", df[df["Country"] == country]["State"].isnull().sum())
# Out:
# Indonesia | States:  ['Sumatra', 'Sulawesi'] | Any nulls in state?:  0
# Brazil | States:  ['Bahia', 'Para'] | Any nulls in state?:  0

# %% [markdown]
# Podstawowy opis danych:
#
# ![image.png](attachment:image.png)
#
# Pola zaakceptowane:
# * Country
# * Week
# * Year
# * Month
# * Total
# * Date
#
# Pola do odrzucenia i dlaczego:
#
# * IsTempRecord - zawiera jedynie jedną wartość False
# * Reporter - zawiera tą samą informację co Country, jednak Country jest bardziej informatywne (cała nazwa kraju z którego pochodzi rekord)
# * State -
# * SiteLetter - pole niepotrzebne, ponieważ nie ma dokładnych danych lokalizacyjnych danego areału.
# * SiteNumber - sytuacja taka sama jak w przypadku SiteLetter
# * TreeNumber - Analiza obejmuje krajową sumę zbiorów, dlatego też zwiększenie granulacji do poziomu poszczególnego drzewa jest zbędne.
# * PCSample - Oprócz 2.1% pustych wartości, resztę stanowi tylko jedna wartość tekstowa
# * Variety - dodatkowa meta informacja niestanowiąca wartości dodanej do prognozy. W dodatku pole puste w 98.9%
# * WB, Monilla T/S, Monilla M/L, Monilla M, Black Pod, Other D/D, Harvest, Drying, Fermentation, Fertilizer, Fungicide, Irrigation - pola do wyrzucenia ze względu na ponda 50%-towe braki.
# * Tiny, Small, Medium, Large, Mature, Ripe, Wilt, Damaged, Healthy, Charelles, Adults - są to ilości poszczególnych rodzajów owowcu, tym co prognozujemy są wszystkie owoce.
# * ID, ts, Main - pola nie wnoszące nic do prognozy
# * Region, CountDay - Sytuacja jak w przypadku State
# * SmallBefore, TinyBefore, MediumBefore, LargeBefore, SmallBefore2, LargeBefore2, Mid - Interesuje nas tylko Total, całkowita wartość zebranych owoców
#
# Pola które mogą przydać się dodatkowo w dalszej analizie:
# * State - pole może być przydatne dla potwierdzenia hipotezy, że zawężenie prognozowanego obszaru (zwiększenie granularności danych) prowadzi do zwiększenia skuteczności prognozy. Analizowane są jednak sumy krajowych zbiorów więc to pole może zostać usunięte.
# * Moisture, Texture, Canopy, Maintenance, Flowers, Leaf flushing - pola te odnzaczają się małym procentem pustych wartości (około 2%) (oprócz Moisture - 21.8%), mogą wnieść dodatkową informację do analizy.
#
# ![image.png](attachment:image-2.png)

# %%
df = df[["Date", "Country", "Total"]]

# %%
df
# Out:
#              Date        Country  Total
# 0      1997-10-01  Cote d Ivoire  111.0
# 1      1997-10-01  Cote d Ivoire  197.0
# 2      1997-10-01  Cote d Ivoire  106.0
# 3      1997-10-01  Cote d Ivoire  231.0
# 4      1997-10-01  Cote d Ivoire  192.0
# ...           ...            ...    ...
# 111608 2023-03-01      Indonesia   54.0
# 111609 2023-03-01      Indonesia  163.0
# 111610 2023-03-01      Indonesia   91.0
# 111611 2023-03-01      Indonesia   69.0
# 111612 2023-03-01      Indonesia   15.0
#
# [111613 rows x 3 columns]

# %%
dict_time_availability = {country: [(df[df["Country"] == country]["Date"].min().date().strftime("%Y-%m-%d"), df[df["Country"] == country]["Date"].max().date().strftime("%Y-%m-%d"))] for country in df["Country"].unique()}
dict_time_availability
# Out:
# {'Cote d Ivoire': [('1997-10-01', '2023-02-01')],
#  'Ghana': [('1999-07-01', '2023-02-01')],
#  'Indonesia': [('1999-12-01', '2023-03-01')],
#  'Cameroon': [('2010-08-01', '2023-03-01')],
#  'Brazil': [('2012-03-01', '2023-03-01')],
#  'Ecuador': [('2018-07-01', '2023-03-01')]}

# %%
# Define the categories and their availability periods
categories = {'Category 1': [('2022-01-01', '2022-03-31'), ('2022-07-01', '2022-09-30')],
              'Category 2': [('2022-04-01', '2022-06-30')],
              'Category 3': [('2022-01-01', '2022-12-31')]}

# Convert the categories data into a DataFrame
df_timeline = pd.DataFrame([(k, start, end) for k, v in dict_time_availability.items() for start, end in v], 
                  columns=['Category', 'Start', 'End'])

# Convert the date strings into datetime objects
df_timeline['Start'] = pd.to_datetime(df_timeline['Start'])
df_timeline['End'] = pd.to_datetime(df_timeline['End'])

# Set up the plot
sns.set_style('whitegrid')
fig, ax = plt.subplots(figsize=(10, 5))

for i, data in df_timeline.iterrows():
    y = [i + 0.5] * len(data)
    ax.hlines(y, data['Start'], data['End'], linewidth=10, color=f'C{i}')


ax.set_yticks(range(len(df["Country"].unique())))
ax.set_yticklabels(df["Country"].unique())


# Set the plot title and axis labels
ax.set_title('Availability of different categories', fontsize=16)
ax.set_xlabel('Timeline', fontsize=14)
ax.set_ylabel('Category', fontsize=14)

# Show the plot
plt.show()

# %%
df
# Out:
#              Date  Year  Month  Week        Country  Total
# 0      1997-10-01  1997     10    44  Cote d Ivoire  111.0
# 1      1997-10-01  1997     10    44  Cote d Ivoire  197.0
# 2      1997-10-01  1997     10    44  Cote d Ivoire  106.0
# 3      1997-10-01  1997     10    44  Cote d Ivoire  231.0
# 4      1997-10-01  1997     10    44  Cote d Ivoire  192.0
# ...           ...   ...    ...   ...            ...    ...
# 111608 2023-03-01  2023      3     0      Indonesia   54.0
# 111609 2023-03-01  2023      3     0      Indonesia  163.0
# 111610 2023-03-01  2023      3     0      Indonesia   91.0
# 111611 2023-03-01  2023      3     0      Indonesia   69.0
# 111612 2023-03-01  2023      3     0      Indonesia   15.0
#
# [111613 rows x 6 columns]

# %% [markdown]
# POL: Dane są zbierane z różnych sektorów->pod-sektorów->drzew, tak więc na jeden miesiąc przypada wiele punktów co nie jest czymś pożądanym. Z tego względu z każdego miesiąca powinna zostać wyciągnięta suma zbiorów. Dlaczego suma? Wynika to z specyfikacji danych. W tym przypadku średnia oznaczałaby średnią wartość zbioru z jednego drzewa, natomiast nas interesuje suma zbioru w kraju z danego miesiąca.
#
# ENG: The data are collected from different different sectors->sub-sectors->trees, so there are multiple points per month which is not something desirable. Therefore, a harvest total should be drawn from each month. Why a total? This is due to the specification of the data. In this case, average would mean the average value of the harvest from one tree, whereas we are interested in the total harvest in the country from a given month.

# %%
df_monthly = df.groupby(['Date', 'Country']).sum()

# %%
df_monthly = df_monthly.reset_index()

# %%
df_monthly
# Out:
#           Date        Country    Total
# 0   1997-10-01  Cote d Ivoire   3873.0
# 1   1998-01-01  Cote d Ivoire   3400.0
# 2   1998-03-01  Cote d Ivoire   2081.0
# 3   1998-05-01  Cote d Ivoire   2175.0
# 4   1998-06-01  Cote d Ivoire   5628.0
# ..         ...            ...      ...
# 831 2023-02-01      Indonesia   3592.0
# 832 2023-03-01         Brazil  11098.0
# 833 2023-03-01       Cameroon    605.0
# 834 2023-03-01        Ecuador   4205.0
# 835 2023-03-01      Indonesia   7579.0
#
# [836 rows x 3 columns]

# %%
sns.boxplot(x='Country', y='Total', data=df_monthly)
# Out:
# <Axes: xlabel='Country', ylabel='Total'>

# %%
# Load sample data
# df_test = sns.load_dataset('flights')
# df_test['year_month'] = pd.to_datetime(df_test['year'].astype(str) + '-' + df_test['month'].astype(str))

# Set up the FacetGrid
g = sns.FacetGrid(df_monthly, col='Country', col_wrap=3, height=3, aspect=1)

# Plot time series data within each subplot
g.map(sns.lineplot, 'Date', 'Total')

# Set plot title and axis labels
g.set_titles('{col_name}')
g.set_xlabels('Date')
g.set_ylabels('Total')

# Adjust plot layout
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Total crop over years for different countries', fontsize=16)

# Show the plot
plt.show()

# %% [markdown]
# Na powyższym zestawieniu wykresów widać, że należy odrzucić dane dotyczące Indonezji ze względu na brak ciągłości oraz odstające próbki a także Ekwador ze względu na zbyt mały zakres próbek.

# %%
df_monthly.drop(df_monthly[df_monthly["Country"] == "Indonesia"].index, inplace=True)
df_monthly.drop(df_monthly[df_monthly["Country"] == "Ecuador"].index, inplace=True)

# %%
df_monthly
# Out:
#           Date        Country    Total
# 0   1997-10-01  Cote d Ivoire   3873.0
# 1   1998-01-01  Cote d Ivoire   3400.0
# 2   1998-03-01  Cote d Ivoire   2081.0
# 3   1998-05-01  Cote d Ivoire   2175.0
# 4   1998-06-01  Cote d Ivoire   5628.0
# ..         ...            ...      ...
# 827 2023-02-01       Cameroon    379.0
# 828 2023-02-01  Cote d Ivoire   6226.0
# 830 2023-02-01          Ghana   3574.0
# 832 2023-03-01         Brazil  11098.0
# 833 2023-03-01       Cameroon    605.0
#
# [716 rows x 3 columns]

# %%
# Set up the FacetGrid
g = sns.FacetGrid(df_monthly, col='Country', col_wrap=2, height=4, aspect=1)

# Plot time series data within each subplot
g.map(sns.lineplot, 'Date', 'Total')

# Set plot title and axis labels
g.set_titles('{col_name}')
g.set_xlabels('Date')
g.set_ylabels('Total')

# Adjust plot layout
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Total crop over years for different countries', fontsize=16)

# Show the plot
plt.show()

# %% [markdown]
# Otrzymane szeregi czasowe nie są ciągłe w czasie, interwał czasowy nie wynosi zawsze miesiąc. Z tego względu należy przeprowadzić interpolację.

# %%
df_monthly.set_index('Date', inplace=True)

# %%
df_monthly_interpolated = pd.DataFrame()
df_monthly_interpolated
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_monthly_interpolated = pd.DataFrame()
for country in df_monthly["Country"].unique():
    period_array = pd.date_range(df_monthly[df_monthly["Country"] == country].head(1).index.values[0], df_monthly[df_monthly["Country"] == country].tail(1).index.values[0] + pd.DateOffset(months=1), freq='M')
    period_array = [i.replace(day=1).date() for i in period_array]
    df_full_period = pd.DataFrame(period_array)
    df_full_period = df_full_period.rename(columns={0: 'Date'})
    df_full_period["Value"] = 0
    df_full_period.set_index("Date", inplace=True)
    df_monthly_new = pd.merge(df_monthly[df_monthly["Country"] == country], df_full_period, right_index=True, left_index=True, how='right')
    df_monthly_new = df_monthly_new.drop(columns=['Value'])
    df_monthly_new["Country"] = df_monthly_new["Country"].fillna(country)
    df_monthly_new.plot(title=country)
    df_monthly_new["Total"] = df_monthly_new["Total"].interpolate()
    print(df_monthly_new)
    df_monthly_new.plot(title=country)
    df_monthly_interpolated = df_monthly_interpolated.append(df_monthly_new)
# Out:
#                   Country        Total
# Date
# 1997-10-01  Cote d Ivoire  3873.000000
# 1997-11-01  Cote d Ivoire  3715.333333
# 1997-12-01  Cote d Ivoire  3557.666667
# 1998-01-01  Cote d Ivoire  3400.000000
# 1998-02-01  Cote d Ivoire  2740.500000
# ...                   ...          ...
# 2022-10-01  Cote d Ivoire  8291.000000
# 2022-11-01  Cote d Ivoire  7598.000000
# 2022-12-01  Cote d Ivoire  6874.000000
# 2023-01-01  Cote d Ivoire  6822.000000
# 2023-02-01  Cote d Ivoire  6226.000000
#
# [305 rows x 2 columns]
#            Country   Total
# Date
# 1999-07-01   Ghana  2994.0
# 1999-08-01   Ghana  3341.5
# 1999-09-01   Ghana  3689.0
# 1999-10-01   Ghana  3561.1
# 1999-11-01   Ghana  3433.2
# ...            ...     ...
# 2022-10-01   Ghana  7575.0
# 2022-11-01   Ghana  6775.0
# 2022-12-01   Ghana  5751.0
# 2023-01-01   Ghana  4145.0
# 2023-02-01   Ghana  3574.0
#
# [284 rows x 2 columns]
#              Country   Total
# Date
# 2010-08-01  Cameroon  9531.0
# 2010-09-01  Cameroon  6536.0
# 2010-10-01  Cameroon  4529.0
# 2010-11-01  Cameroon  2544.0
# 2010-12-01  Cameroon  1576.0
# ...              ...     ...
# 2022-11-01  Cameroon  2471.0
# 2022-12-01  Cameroon  1225.0
# 2023-01-01  Cameroon   534.0
# 2023-02-01  Cameroon   379.0
# 2023-03-01  Cameroon   605.0
#
# [152 rows x 2 columns]
#            Country    Total
# Date
# 2012-03-01  Brazil   8384.0
# 2012-04-01  Brazil   9469.0
# 2012-05-01  Brazil   8389.0
# 2012-06-01  Brazil   8222.0
# 2012-07-01  Brazil   8055.0
# ...            ...      ...
# 2022-11-01  Brazil   4486.0
# 2022-12-01  Brazil   2661.0
# 2023-01-01  Brazil   8361.0
# 2023-02-01  Brazil   3736.0
# 2023-03-01  Brazil  11098.0
#
# [133 rows x 2 columns]
# C:\Users\BC127735\AppData\Local\Temp\ipykernel_6172\936622619.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_monthly_interpolated = df_monthly_interpolated.append(df_monthly_new)
# C:\Users\BC127735\AppData\Local\Temp\ipykernel_6172\936622619.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_monthly_interpolated = df_monthly_interpolated.append(df_monthly_new)
# C:\Users\BC127735\AppData\Local\Temp\ipykernel_6172\936622619.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_monthly_interpolated = df_monthly_interpolated.append(df_monthly_new)
# C:\Users\BC127735\AppData\Local\Temp\ipykernel_6172\936622619.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_monthly_interpolated = df_monthly_interpolated.append(df_monthly_new)

# %%
df_monthly_interpolated
# Out:
#                   Country         Total
# Date
# 1997-10-01  Cote d Ivoire   3873.000000
# 1997-11-01  Cote d Ivoire   3715.333333
# 1997-12-01  Cote d Ivoire   3557.666667
# 1998-01-01  Cote d Ivoire   3400.000000
# 1998-02-01  Cote d Ivoire   2740.500000
# ...                   ...           ...
# 2022-11-01         Brazil   4486.000000
# 2022-12-01         Brazil   2661.000000
# 2023-01-01         Brazil   8361.000000
# 2023-02-01         Brazil   3736.000000
# 2023-03-01         Brazil  11098.000000
#
# [874 rows x 2 columns]

# %% [markdown]
# ## Decomposition

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
for country in df_monthly_interpolated["Country"].unique():
    decomp = seasonal_decompose(df_monthly_interpolated[df_monthly_interpolated["Country"] == country].drop(columns=["Country"]))
    # Plot the decomposition
    fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=(12, 8))
    decomp.observed.plot(ax=ax1)
    ax1.set_ylabel('Observed')
    decomp.trend.plot(ax=ax2)
    ax2.set_ylabel('Trend')
    decomp.seasonal.plot(ax=ax3)
    ax3.set_ylabel('Seasonal')
    decomp.resid.plot(ax=ax4)
    ax4.set_ylabel('Residual')

    # Add a title to the plot
    fig.suptitle(country)

    # Show the plot
    plt.show()

# %% [markdown]
# Wszystkie wykresy cechują się silną sezonowością co może być podstawą do hipotezy, że model SARIMA będzie wykazywał lepsze wyniki niż ARIMA. Cote d Ivoire oraz Ghana cechują się wzrostowym trendem, natomiast Cameroon oraz Brazylia trendem spadkowym. Sezonowość może być dobrze wyjaśniona przez naturę zbiorów jakichkolwiek upraw. Uprawy muszą rosnąć, więc w szczycie zbiorów będzie ich najwięcej, podczas gdy poza sezonem będzie ich bardzo mało.

# %% [markdown]
# ## ACF: the autocorrelation function

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
for country in df_monthly_interpolated["Country"].unique():
    plot_acf(df_monthly_interpolated[df_monthly_interpolated["Country"] == country].drop(columns=["Country"]), title=country)

# %% [markdown]
# Trudności w predykcji mogą pojawić się dla danych dotyczących Brazylii.

# %% [markdown]
# ## PACF: the partial autocorrelation function

# %%
from statsmodels.graphics.tsaplots import plot_pacf

# %%
for country in df_monthly_interpolated["Country"].unique():
    plot_pacf(df_monthly_interpolated[df_monthly_interpolated["Country"] == country].drop(columns=["Country"]), title=country)
# Out:
# c:\Users\BC127735\Anaconda3\envs\venv39ML\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(
# c:\Users\BC127735\Anaconda3\envs\venv39ML\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(
# c:\Users\BC127735\Anaconda3\envs\venv39ML\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(
# c:\Users\BC127735\Anaconda3\envs\venv39ML\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
from pandas.plotting import lag_plot

# %%
for country in df_monthly_interpolated["Country"].unique():
    plt.title(country)
    lag_plot(df_monthly_interpolated[df_monthly_interpolated["Country"] == country].drop(columns=["Country"]))
    plt.show()

# %% [markdown]
# Ponownie wykres rozrzutu opóźnień pokazuje słabą korelację pomiędzy opóźnionymi próbkami czasowymi dla terenów Brazylii. Silna pozytywna korelacja występuje natomiast dla Cote d Ivoire oraz Ghany.

# %% [markdown]
# ## Stationarity: Dickey-Fuller test

# %%
from statsmodels.tsa.stattools import adfuller

# %%
for country in df_monthly_interpolated["Country"].unique():
    adf, pval, usedlag, nobs, crit_vals, icbest =  adfuller(df_monthly_interpolated[df_monthly_interpolated["Country"] == country].drop(columns=["Country"]).Total.values)
    print("********************")
    print(country)
    print('ADF test statistic:', adf)
    print('ADF p-values:', pval)
    print('ADF number of lags used:', usedlag)
    print('ADF number of observations:', nobs)
    print('ADF critical values:', crit_vals)
    print('ADF best information criterion:', icbest)
# Out:
# ********************
# Cote d Ivoire
# ADF test statistic: -1.3403318118192886
# ADF p-values: 0.6105245287280866
# ADF number of lags used: 12
# ADF number of observations: 292
# ADF critical values: {'1%': -3.4529449243622383, '5%': -2.871489553425686, '10%': -2.572071437887033}
# ADF best information criterion: 4675.459057755774
# ********************
# Ghana
# ADF test statistic: -1.88610344369741
# ADF p-values: 0.33862646276112773
# ADF number of lags used: 14
# ADF number of observations: 269
# ADF critical values: {'1%': -3.4548957220044336, '5%': -2.8723451788613157, '10%': -2.572527778361272}
# ADF best information criterion: 4256.937994762562
# ********************
# Cameroon
# ADF test statistic: -1.3660043850303925
# ADF p-values: 0.5984612287499577
# ADF number of lags used: 12
# ADF number of observations: 139
# ADF critical values: {'1%': -3.4782936965183815, '5%': -2.882567574015525, '10%': -2.5779830117488745}
# ADF best information criterion: 2402.7749887233654
# ********************
# Brazil
# ADF test statistic: -2.7643891847747244
# ADF p-values: 0.06354331524536702
# ADF number of lags used: 13
# ADF number of observations: 119
# ADF critical values: {'1%': -3.4865346059036564, '5%': -2.8861509858476264, '10%': -2.579896092790057}
# ADF best information criterion: 2172.213582523

# %% [markdown]
# POL: p-wartość jest powyżej 0.05 a więc nie można przyjąć hipotezy alternatywnej o stacjonarności. Szeregi czasowe są więc nie-stacjonarne. Najbliżej stacjonarności jest szereg czasowy dla danych Brazylii - około 6% wartości p.
#
# ENG: The p-value is above 0.05 and so the alternative hypothesis of stationarity cannot be accepted. The time series are therefore non-stationary.
