# %%
from BC_solutions import Databases
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt

# %%
# Database credentials
server = 'CorpPolDB'
database = 'DW'
UID = 'POD'
PWD = 'POD2019'

database_manager = Databases.DatabaseManager(server, database, UID, PWD)
# Out:
# POD POD2019
# Connection with database established.

# %%
df = database_manager.get_data('SELECT * FROM [DW].[pod].[v_POD]')

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    IsTempRecord Reporter        Country State  Week  Year  Month SiteLetter  \
# 0         False      CIV  Cote d Ivoire   n/a    44  1997     10         AG
# 1         False      CIV  Cote d Ivoire   n/a    44  1997     10         AG
# 2         False      CIV  Cote d Ivoire   n/a    44  1997     10         AG
# 3         False      CIV  Cote d Ivoire   n/a    44  1997     10         AG
# 4         False      CIV  Cote d Ivoire   n/a    44  1997     10         AG
#
#    SiteNumber  TreeNumber PCSample Variety  Moisture  Texture  Canopy  \
# 0           2           0        Y     n/a       NaN      NaN     NaN
# 1          10           0        Y     n/a       NaN      NaN     NaN
# 2          11           0        Y     n/a       NaN      NaN     NaN
# 3          12           0        Y     n/a       NaN      NaN     NaN
# 4          13           0        Y     n/a       NaN      NaN     NaN
#
#    Maintenance  Flowers  Leaf flushing  WB  Monilia T/S  Monilia M/L  \
# ...

# %%
print(df.columns)
# Out:
# Index(['IsTempRecord', 'Reporter', 'Country', 'State', 'Week', 'Year', 'Month',
#        'SiteLetter', 'SiteNumber', 'TreeNumber', 'PCSample', 'Variety',
#        'Moisture', 'Texture', 'Canopy', 'Maintenance', 'Flowers',
#        'Leaf flushing', 'WB', 'Monilia T/S', 'Monilia M/L', 'Monilia M',
#        'Black Pod', 'Other D/D', 'Harvest', 'Drying', 'Fermentation',
#        'Fertilizer', 'Fungicide', 'Irrigation', 'Tiny', 'Small', 'Medium',
#        'Large', 'Mature', 'Ripe', 'Wilt', 'Damaged', 'Healthy', 'Total',
#        'Cherelles', 'Adults', 'ImportDate', 'ID', 'ts', 'Main', 'Region',
#        'CountDay', 'SmallBefore', 'TinyBefore', 'MediumBefore', 'LargeBefore',
#        'SmallBefore2', 'LargeBefore2', 'Mid'],
#       dtype='object')

# %%
df_2 = df[['Country', 'Year', 'Month', 'Total']]

# %%
df_2['Date'] = [datetime(row["Year"], row["Month"], 1) for index, row in df_2.iterrows()]
# Out:
# C:\Users\BC127735\AppData\Local\Temp\ipykernel_21464\1107058262.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['Date'] = [datetime(row["Year"], row["Month"], 1) for index, row in df_2.iterrows()]

# %%
df_3 = df_2[['Date', 'Country', 'Total']]

# %%
df_3
# Out:
#              Date        Country  Total
# 0      1997-10-01  Cote d Ivoire  111.0
# 1      1997-10-01  Cote d Ivoire  197.0
# 2      1997-10-01  Cote d Ivoire  106.0
# 3      1997-10-01  Cote d Ivoire  231.0
# 4      1997-10-01  Cote d Ivoire  192.0
# ...           ...            ...    ...
# 111314 2023-03-01      Indonesia   54.0
# 111315 2023-03-01      Indonesia  163.0
# 111316 2023-03-01      Indonesia   91.0
# 111317 2023-03-01      Indonesia   69.0
# 111318 2023-03-01      Indonesia   15.0
#
# [111319 rows x 3 columns]

# %%
df_3.set_index('Date', inplace=True)
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 111319 entries, 1997-10-01 to 2023-03-01
# Data columns (total 2 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   Country  111319 non-null  object
#  1   Total    111319 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 2.5+ MB

# %%
df_3
# Out:
#                   Country  Total
# Date
# 1997-10-01  Cote d Ivoire  111.0
# 1997-10-01  Cote d Ivoire  197.0
# 1997-10-01  Cote d Ivoire  106.0
# 1997-10-01  Cote d Ivoire  231.0
# 1997-10-01  Cote d Ivoire  192.0
# ...                   ...    ...
# 2023-03-01      Indonesia   54.0
# 2023-03-01      Indonesia  163.0
# 2023-03-01      Indonesia   91.0
# 2023-03-01      Indonesia   69.0
# 2023-03-01      Indonesia   15.0
#
# [111319 rows x 2 columns]

# %%
df_3.to_csv('Pod_prepared.txt')
